# %% [markdown]
# # Stable Audio
# https://huggingface.co/stabilityai/stable-audio-open-1.0

# %%
# !pip install torchsde
import torch
import soundfile as sf
from diffusers import StableAudioPipeline
from IPython.display import Audio  # Import the Audio module for playback

pipe = StableAudioPipeline.from_pretrained("stabilityai/stable-audio-open-1.0", torch_dtype=torch.float16)
pipe = pipe.to("cuda")

# define the prompts
prompt = "Lo-fi jungle insect creature chirping with wooden resonance and humid forest ambience incorporated with beats in summer breeze."
negative_prompt = "harsh noise."

# set the seed for generator
generator = torch.Generator("cuda")

# run the generation
audio = pipe(
    prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=200,
    audio_end_in_s=16,
    num_waveforms_per_prompt=3,
    generator=generator,
).audios

output = audio[0].T.float().cpu().numpy()
sf.write("output.wav", output, pipe.vae.sampling_rate)

# Play the audio in Colab
Audio("output.wav")
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import userdata
HF_TOKEN = userdata.get('HF_TOKEN')
if HF_TOKEN is None:
    print('Please add your Hugging Face token to Colab secrets as HF_TOKEN.')
